# %%
from azureml.cr

# %%
from azureml.core import *
import azureml.dataprep as dprep

# %%
ws = Workspace.get("myworkspace", subscription_id='ff711122-6294-4fad-9d1f-bf505a51fc42',
               resource_group='mlproject',
               location='westus2')

# %%
titanic=Dataset.auto_read_files("C:/Users/User/Desktop/ML Projects in Git/Azure-Machine-Learning-Service/titanic.csv")

# %%
# titanic_ds=Dataset.Tabular.from_delimited_files("C:/Users/User/Desktop/ML Projects in Git/Azure-Machine-Learning-Service/titanic.csv")

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292  None        Q
# 1   363272   7.0000  None        S
# 2   240276   9.6875  None        Q
# 3   315154   8.6625  None        S
# 4  3101298  12.2875  None        S

# %% [markdown]
# # Change the titanic azure dataset to Pandas DataFrame

# %%
pd_df=titanic.to_pandas_dataframe()

# %%
pd_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292  None        Q
# 1   363272   7.0000  None        S
# 2   240276   9.6875  None        Q
# 3   315154   8.6625  None        S
# 4  3101298  12.2875  None        S

# %% [markdown]
# # Fill missing data by imputed function
